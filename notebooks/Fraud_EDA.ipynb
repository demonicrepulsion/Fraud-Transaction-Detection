# %%
import pandas as pd

df = pd.read_csv("../data/fraud_data.csv")

df.head()
# Out:
#         amount  transactions_today  distance_from_home  international  fraud
# 0  1878.955193                   4          300.563885              1      0
# 1  4754.064389                  18          797.324463              0      0
# 2  3662.649770                   5          672.982307              0      0
# 3  2997.305836                  16          436.208764              0      0
# 4   788.533016                  14          256.253614              0      0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amount              10000 non-null  float64
#  1   transactions_today  10000 non-null  int64
#  2   distance_from_home  10000 non-null  float64
#  3   international       10000 non-null  int64
#  4   fraud               10000 non-null  int64
# dtypes: float64(2), int64(3)
# memory usage: 390.8 KB

# %%
df.describe()
# Out:
#              amount  transactions_today  distance_from_home  international  \
# count  10000.000000        10000.000000        10000.000000   10000.000000
# mean    2475.856193           10.084400          504.113166       0.511500
# std     1435.274331            5.513068          289.385400       0.499893
# min       10.058057            1.000000            0.009296       0.000000
# 25%     1239.181056            5.000000          255.010770       0.000000
# 50%     2467.717801           10.000000          505.702122       1.000000
# 75%     3702.631678           15.000000          755.660992       1.000000
# max     4998.591190           19.000000          999.891062       1.000000
#
#               fraud
# count  10000.000000
# mean       0.100600
# std        0.300813
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df["fraud"].value_counts()
# Out:
# fraud
# 0    8994
# 1    1006
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["fraud"].value_counts().plot(kind="bar")

plt.title("Fraud vs Non-Fraud Transactions")
plt.xlabel("Fraud")
plt.ylabel("Count")
plt.show()
